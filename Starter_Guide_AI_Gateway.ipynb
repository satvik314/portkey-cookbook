# %% [markdown]
# <a href="https://colab.research.google.com/github/satvik314/portkey-cookbook/blob/main/Starter_Guide_AI_Gateway.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# COMING SOON!
